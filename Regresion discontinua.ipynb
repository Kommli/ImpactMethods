# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
from matplotlib import style
from matplotlib import pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf

# %matplotlib inline

style.use("fivethirtyeight")

from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-186a7df0-26e0-4389-96bf-4b63f7661328" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-186a7df0-26e0-4389-96bf-4b63f7661328">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving DatosEducacion.xlsx to DatosEducacion.xlsx

# %%
df = pd.read_excel("DatosEducacion.xlsx")
#Solo cuando es necesario, se puede utilizar encoding, encoding='latin-1' ejemplo:
# df = pd.read_excel("DatosEducacion.xlsx", encoding='latin-1')

# %%
print("Numero total de observaciones = {}".format(df.shape[0]))
print("Numero total de variables = {}".format(df.shape[1]))
# Out:
# Numero total de observaciones = 668
# Numero total de variables = 16

# %%
df.sample(10)
#df.head()
# Out:
#      DIRECTORIO  P1_DEPARTAMENTO  SECUENCIA_ENCUESTA  NivelEducativoCursado  \
# 439     3013649               25                   3                      4
# 178     2999850               25                   3                      7
# 142     3009555               25                   3                      3
# 177     2995137               25                   3                      2
# 419     3008981               25                   3                      3
# 181     2996866               25                   3                      3
# 305     3013457               25                   3                      3
# 106     2999241               25                   3                      2
# 84      2999851               25                   4                      2
# 558     2997078               25                   4                      2
#
#      TipoEstablecimiento  UbicacionColegio  MinutosAColegio  AlimentosEscuela  \
# ...

# %%
df['MinutosAColegio'].describe()
# Out:
# count    668.000000
# mean      23.995509
# std       26.575597
# min        5.000000
# 25%       10.000000
# 50%       15.000000
# 75%       30.000000
# max      180.000000
# Name: MinutosAColegio, dtype: float64

# %%
df["MinutosAColegio"] -= 140

# %%
df
# Out:
#      DIRECTORIO  P1_DEPARTAMENTO  SECUENCIA_ENCUESTA  NivelEducativoCursado  \
# 0       3013752               25                   3                      4
# 1       3003749               25                   2                      2
# 2       3016628               25                   4                      2
# 3       2998448               25                   3                      4
# 4       3008596               25                   2                      7
# ..          ...              ...                 ...                    ...
# 663     2995748               25                   4                      3
# 664     3008083               25                   3                      3
# 665     2996882               25                   3                      1
# 666     3009224               25                   6                      2
# 667     2999855               25                   3                      3
#
# ...

# %%
rdd_df = df.assign(threshold=(df["MinutosAColegio"] > 0).astype(int))

model = smf.wls("NivelEducativoCursado~MinutosAColegio*threshold*TratamientoFin+PagoMatricula+AlimentosEscuela", rdd_df).fit()

print(model.summary())
# Out:
#                               WLS Regression Results
# ...
# Dep. Variable:     NivelEducativoCursado   R-squared:                       0.419
# Model:                               WLS   Adj. R-squared:                  0.413
# Method:                    Least Squares   F-statistic:                     68.13
# Date:                   Thu, 19 May 2022   Prob (F-statistic):           8.04e-74
# Time:                           17:23:56   Log-Likelihood:                -1077.4
# No. Observations:                    668   AIC:                             2171.
# Df Residuals:                        660   BIC:                             2207.
# Df Model:                              7
# Covariance Type:               nonrobust
# ...
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# ...
